# %% [markdown]
# # DATA CLEANING OF A DATA SET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IMPORT THE DATA SET HERE

# %%
churn=pd.read_csv(r"C:\Users\sopra steria 4\OneDrive\Desktop\DATASET\Churn_Modelling_with_nulls.csv")
churn
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 0             1  15634602.0   Hargrave        619.0    France  Female   NaN
# 1             2  15647311.0       Hill        608.0     Spain  Female  41.0
# 2             3  15619304.0       Onio        502.0    France  Female  42.0
# 3             4  15701354.0       Boni        699.0    France  Female  39.0
# 4             5  15737888.0   Mitchell        850.0     Spain  Female  43.0
# ...         ...         ...        ...          ...       ...     ...   ...
# 9995       9996  15606229.0   Obijiaku        771.0    France    Male  39.0
# 9996       9997  15569892.0  Johnstone        516.0    France    Male  35.0
# 9997       9998  15584532.0        Liu        709.0    France  Female  36.0
# 9998       9999  15682355.0  Sabbatini        772.0   Germany    Male  42.0
# 9999      10000  15628319.0     Walker        792.0    France  Female  28.0
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0        2.0       0.00            1.0        1.0             1.0
# 1        1.0   83807.86            1.0        0.0             1.0
# 2        8.0  159660.80            3.0        1.0             0.0
# 3        1.0       0.00            2.0        0.0             0.0
# 4        NaN  125510.82            1.0        1.0             1.0
# ...      ...        ...            ...        ...             ...
# 9995     5.0       0.00            2.0        1.0             0.0
# 9996    10.0   57369.61            1.0        1.0             1.0
# 9997     7.0       0.00            1.0        0.0             1.0
# 9998     3.0   75075.31            2.0        1.0             0.0
# 9999     NaN  130142.79            1.0        1.0             0.0
#
#       EstimatedSalary  Exited
# 0           101348.88     1.0
# 1           112542.58     0.0
# 2           113931.57     1.0
# 3            93826.63     0.0
# 4            79084.10     0.0
# ...               ...     ...
# 9995         96270.64     0.0
# 9996        101699.77     0.0
# 9997         42085.58     1.0
# 9998         92888.52     1.0
# 9999         38190.78     0.0
#
# [10000 rows x 14 columns]

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1  15634602.0  Hargrave        619.0    France  Female   NaN
# 1          2  15647311.0      Hill        608.0     Spain  Female  41.0
# 2          3  15619304.0      Onio        502.0    France  Female  42.0
# 3          4  15701354.0      Boni        699.0    France  Female  39.0
# 4          5  15737888.0  Mitchell        850.0     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00            1.0        1.0             1.0
# 1     1.0   83807.86            1.0        0.0             1.0
# 2     8.0  159660.80            3.0        1.0             0.0
# 3     1.0       0.00            2.0        0.0             0.0
# 4     NaN  125510.82            1.0        1.0             1.0
#
#    EstimatedSalary  Exited
# 0        101348.88     1.0
# 1        112542.58     0.0
# 2        113931.57     1.0
# 3         93826.63     0.0
# 4         79084.10     0.0

# %% [markdown]
# # Check Whether The DataFrame Has NUll Values or not (False means valid value True means null value)

# %%
churn.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False   True
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0      False    False          False      False           False
# 1      False    False          False      False           False
# 2      False    False          False      False           False
# 3      False    False          False      False           False
# 4       True    False          False      False           False
# ...      ...      ...            ...        ...             ...
# 9995   False    False          False      False           False
# 9996   False    False          False      False           False
# 9997   False    False          False      False           False
# 9998   False    False          False      False           False
# 9999    True    False          False      False           False
#
#       EstimatedSalary  Exited
# 0               False   False
# 1               False   False
# 2               False   False
# 3               False   False
# 4               False   False
# ...               ...     ...
# 9995            False   False
# 9996            False   False
# 9997            False   False
# 9998            False   False
# 9999            False   False
#
# [10000 rows x 14 columns]

# %% [markdown]
# # check the number of null values in the data frame

# %%
churn.isnull().sum()
# Out:
# RowNumber            0
# CustomerId         495
# Surname            533
# CreditScore        516
# Geography          502
# Gender             481
# Age                519
# Tenure             514
# Balance            497
# NumOfProducts      486
# HasCrCard          497
# IsActiveMember     497
# EstimatedSalary    481
# Exited             478
# dtype: int64

# %% [markdown]
# # seperate the numerical values from the data frame

# %%
numerical_churn = churn.select_dtypes(include=['int', 'float'])

# %%
numerical_churn.head()
# Out:
#    RowNumber  CustomerId  CreditScore   Age  Tenure    Balance  NumOfProducts  \
# 0          1  15634602.0        619.0   NaN     2.0       0.00            1.0
# 1          2  15647311.0        608.0  41.0     1.0   83807.86            1.0
# 2          3  15619304.0        502.0  42.0     8.0  159660.80            3.0
# 3          4  15701354.0        699.0  39.0     1.0       0.00            2.0
# 4          5  15737888.0        850.0  43.0     NaN  125510.82            1.0
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        1.0             1.0        101348.88     1.0
# 1        0.0             1.0        112542.58     0.0
# 2        1.0             0.0        113931.57     1.0
# 3        0.0             0.0         93826.63     0.0
# 4        1.0             1.0         79084.10     0.0

# %% [markdown]
# # Seperate the categorical columns

# %%
categorical_churn = churn.select_dtypes(include=['object', 'category','string'])

# %%
categorical_churn.head()
# Out:
#     Surname Geography  Gender
# 0  Hargrave    France  Female
# 1      Hill     Spain  Female
# 2      Onio    France  Female
# 3      Boni    France  Female
# 4  Mitchell     Spain  Female

# %% [markdown]
# # Print the numerical and categorical columns

# %%
print("   Numerical columns   ")
print(numerical_churn.columns)
# Out:
#    Numerical columns
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='str')

# %% [markdown]
# # print the categorical columns

# %%
print("    categorical columns   ")
print(categorical_churn.columns)
# Out:
#     categorical columns
# Index(['Surname', 'Geography', 'Gender'], dtype='str')

# %% [markdown]
# # calculate the median of the columns of numerical columns

# %%
numerical_churn.median()
# Out:
# RowNumber              5000.50
# CustomerId         15690670.00
# CreditScore             652.00
# Age                      37.00
# Tenure                    5.00
# Balance               97042.60
# NumOfProducts             1.00
# HasCrCard                 1.00
# IsActiveMember            1.00
# EstimatedSalary      100187.43
# Exited                    0.00
# dtype: float64

# %% [markdown]
# # calculate mean of the categorical column or we can say that we need to see the most frequntly appearing value

# %%
categorical_churn.mode()
# Out:
#   Surname Geography Gender
# 0   Smith    France   Male

# %% [markdown]
# # replace all the null values in categorical columns with its mean

# %%
for col in categorical_churn.columns:
    most_frequent = categorical_churn[col].mode()[0]
    categorical_churn[col] = categorical_churn[col].replace(np.nan, most_frequent)

categorical_churn.isnull().sum()
# Out:
# Surname      0
# Geography    0
# Gender       0
# dtype: int64

# %% [markdown]
# # replace the null values in numerical columns with its median

# %%
numerical_churn = numerical_churn.replace(np.nan, numerical_churn.median())
numerical_churn.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # by using concat we need to glue both the data frame into one

# %%
churn_clean = pd.concat([numerical_churn, categorical_churn], axis=1)
churn_clean.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# Surname            0
# Geography          0
# Gender             0
# dtype: int64

# %% [markdown]
# # how many customer left\exited

# %%
sns.countplot(data=churn_clean, x='Exited')
plt.title('Distribution of Customer Churn')
plt.show()

# %% [markdown]
# # Create a new dataframe for churn1 and drop columns that don't help predict churn

# %%
churn1 = churn_clean.drop(columns=['RowNumber', 'CustomerId', 'Surname'])
churn1
# Out:
#       CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0           619.0  37.0     2.0       0.00            1.0        1.0
# 1           608.0  41.0     1.0   83807.86            1.0        0.0
# 2           502.0  42.0     8.0  159660.80            3.0        1.0
# 3           699.0  39.0     1.0       0.00            2.0        0.0
# 4           850.0  43.0     5.0  125510.82            1.0        1.0
# ...           ...   ...     ...        ...            ...        ...
# 9995        771.0  39.0     5.0       0.00            2.0        1.0
# 9996        516.0  35.0    10.0   57369.61            1.0        1.0
# 9997        709.0  36.0     7.0       0.00            1.0        0.0
# 9998        772.0  42.0     3.0   75075.31            2.0        1.0
# 9999        792.0  28.0     5.0  130142.79            1.0        1.0
#
#       IsActiveMember  EstimatedSalary  Exited Geography  Gender
# 0                1.0        101348.88     1.0    France  Female
# 1                1.0        112542.58     0.0     Spain  Female
# 2                0.0        113931.57     1.0    France  Female
# 3                0.0         93826.63     0.0    France  Female
# 4                1.0         79084.10     0.0     Spain  Female
# ...              ...              ...     ...       ...     ...
# 9995             0.0         96270.64     0.0    France    Male
# 9996             1.0        101699.77     0.0    France    Male
# 9997             1.0         42085.58     1.0    France  Female
# 9998             0.0         92888.52     1.0   Germany    Male
# 9999             0.0         38190.78     0.0    France  Female
#
# [10000 rows x 11 columns]

# %% [markdown]
# # use one hot encoding for geography and gender

# %%
X_encoded = pd.get_dummies(churn1, columns=['Geography', 'Gender'], drop_first=True)
X_encoded
# Out:
#       CreditScore   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0           619.0  37.0     2.0       0.00            1.0        1.0
# 1           608.0  41.0     1.0   83807.86            1.0        0.0
# 2           502.0  42.0     8.0  159660.80            3.0        1.0
# 3           699.0  39.0     1.0       0.00            2.0        0.0
# 4           850.0  43.0     5.0  125510.82            1.0        1.0
# ...           ...   ...     ...        ...            ...        ...
# 9995        771.0  39.0     5.0       0.00            2.0        1.0
# 9996        516.0  35.0    10.0   57369.61            1.0        1.0
# 9997        709.0  36.0     7.0       0.00            1.0        0.0
# 9998        772.0  42.0     3.0   75075.31            2.0        1.0
# 9999        792.0  28.0     5.0  130142.79            1.0        1.0
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                1.0        101348.88     1.0              False
# 1                1.0        112542.58     0.0              False
# 2                0.0        113931.57     1.0              False
# 3                0.0         93826.63     0.0              False
# 4                1.0         79084.10     0.0              False
# ...              ...              ...     ...                ...
# 9995             0.0         96270.64     0.0              False
# 9996             1.0        101699.77     0.0              False
# 9997             1.0         42085.58     1.0              False
# 9998             0.0         92888.52     1.0               True
# 9999             0.0         38190.78     0.0              False
#
#       Geography_Spain  Gender_Male
# 0               False        False
# 1                True        False
# 2               False        False
# 3               False        False
# 4                True        False
# ...               ...          ...
# 9995            False         True
# 9996            False         True
# 9997            False        False
# 9998            False         True
# 9999            False        False
#
# [10000 rows x 12 columns]

# %% [markdown]
# # seperate features (X) and targetr (y)

# %%
X = X_encoded.drop(columns=['Exited'])
y = X_encoded['Exited']
X
y
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 9995    0.0
# 9996    0.0
# 9997    1.0
# 9998    1.0
# 9999    0.0
# Name: Exited, Length: 10000, dtype: float64

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X_scaled.head()
# Out:
#    CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0    -0.337712 -0.178941 -1.069962 -1.268270      -0.873496   0.625311
# 1    -0.454729  0.212444 -1.425478  0.105559      -0.873496  -1.599204
# 2    -1.582356  0.310290  1.063136  1.348985       2.585210   0.625311
# 3     0.513328  0.016751 -1.425478 -1.268270       0.855857  -1.599204
# 4     2.119664  0.408136 -0.003413  0.789178      -0.873496   0.625311
#
#    IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0        0.927799         0.021420          -0.559024        -0.557329
# 1        0.927799         0.220639          -0.559024         1.794271
# 2       -1.077819         0.245359          -0.559024        -0.557329
# 3       -1.077819        -0.112457          -0.559024        -0.557329
# 4        0.927799        -0.374836          -0.559024         1.794271
#
#    Gender_Male
# 0    -1.144786
# 1    -1.144786
# 2    -1.144786
# 3    -1.144786
# 4    -1.144786

# %% [markdown]
# # Split the data: 80% for training, 20% for testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
X_train.shape
X_test.shape
# Out:
# (2000, 11)

# %% [markdown]
# # Train the model it will predict wheter a customer will stay or leave

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred):.2%}\n")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 81.85%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.97      0.90      1635
#          1.0       0.51      0.15      0.24       365
#
#     accuracy                           0.82      2000
#    macro avg       0.67      0.56      0.57      2000
# weighted avg       0.78      0.82      0.78      2000

# %% [markdown]
# # confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Stayed', 'Exited'])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# %% [markdown]
# # save it in as a csv file so it will not be lost

# %%
churn_clean.to_csv("Cleaned_Churn_Modeling.csv", index=False)
print("Dataset successfully saved!")
# Out:
# Dataset successfully saved!

# %% [markdown]
# # import tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
model_tf = Sequential()
model_tf.add(Dense(units=16, activation='relu', input_dim=X_train.shape[1]))
model_tf.add(Dropout(0.2)) 
model_tf.add(Dense(units=8, activation='relu'))
model_tf.add(Dropout(0.2))
model_tf.add(Dense(units=1, activation='sigmoid'))
model_tf.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy'])
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model_tf.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,  
    callbacks=[early_stop]
)
loss, accuracy = model_tf.evaluate(X_test, y_test)
print(f"\nTensorFlow Model Test Accuracy: {accuracy:.2%}")
# Out:
# C:\Users\sopra steria 4\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7044 - loss: 0.6070 - val_accuracy: 0.8081 - val_loss: 0.4715
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8028 - loss: 0.4815 - val_accuracy: 0.8138 - val_loss: 0.4319
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8094 - loss: 0.4589 - val_accuracy: 0.8231 - val_loss: 0.4188
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8119 - loss: 0.4452 - val_accuracy: 0.8363 - val_loss: 0.4129
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8170 - loss: 0.4401 - val_accuracy: 0.8381 - val_loss: 0.4069
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8167 - loss: 0.4318 - val_accuracy: 0.8375 - val_loss: 0.4015
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8236 - loss: 0.4261 - val_accuracy: 0.8406 - val_loss: 0.3975
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8294 - loss: 0.4180 - val_accuracy: 0.8431 - val_loss: 0.3910
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8309 - loss: 0.4145 - val_accuracy: 0.8475 - val_loss: 0.3869
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8341 - loss: 0.4011 - val_accuracy: 0.8481 - val_loss: 0.3824
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8325 - loss: 0.4066 - val_accuracy: 0.8519 - val_loss: 0.3798
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8352 - loss: 0.4079 - val_accuracy: 0.8487 - val_loss: 0.3775
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8363 - loss: 0.4021 - val_accuracy: 0.8519 - val_loss: 0.3759
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8402 - loss: 0.3937 - val_accuracy: 0.8519 - val_loss: 0.3717
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8411 - loss: 0.3923 - val_accuracy: 0.8519 - val_loss: 0.3685
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8403 - loss: 0.3891 - val_accuracy: 0.8494 - val_loss: 0.3680
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8428 - loss: 0.3807 - val_accuracy: 0.8544 - val_loss: 0.3644
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8397 - loss: 0.3901 - val_accuracy: 0.8531 - val_loss: 0.3660
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8394 - loss: 0.3920 - val_accuracy: 0.8537 - val_loss: 0.3652
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8425 - loss: 0.3833 - val_accuracy: 0.8537 - val_loss: 0.3613
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8427 - loss: 0.3849 - val_accuracy: 0.8556 - val_loss: 0.3612
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8428 - loss: 0.3767 - val_accuracy: 0.8556 - val_loss: 0.3595
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8425 - loss: 0.3800 - val_accuracy: 0.8562 - val_loss: 0.3595
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8445 - loss: 0.3798 - val_accuracy: 0.8587 - val_loss: 0.3582
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8469 - loss: 0.3751 - val_accuracy: 0.8587 - val_loss: 0.3580
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8466 - loss: 0.3728 - val_accuracy: 0.8587 - val_loss: 0.3561
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8436 - loss: 0.3747 - val_accuracy: 0.8606 - val_loss: 0.3562
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8458 - loss: 0.3736 - val_accuracy: 0.8587 - val_loss: 0.3575
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8444 - loss: 0.3745 - val_accuracy: 0.8619 - val_loss: 0.3561
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8450 - loss: 0.3717 - val_accuracy: 0.8612 - val_loss: 0.3554
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8500 - loss: 0.3658 - val_accuracy: 0.8575 - val_loss: 0.3539
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8431 - loss: 0.3734 - val_accuracy: 0.8625 - val_loss: 0.3536
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8475 - loss: 0.3706 - val_accuracy: 0.8581 - val_loss: 0.3556
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8502 - loss: 0.3676 - val_accuracy: 0.8606 - val_loss: 0.3550
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8502 - loss: 0.3652 - val_accuracy: 0.8631 - val_loss: 0.3537
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8534 - loss: 0.3647 - val_accuracy: 0.8612 - val_loss: 0.3526
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8512 - loss: 0.3615 - val_accuracy: 0.8606 - val_loss: 0.3518
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8494 - loss: 0.3683 - val_accuracy: 0.8631 - val_loss: 0.3523
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8478 - loss: 0.3675 - val_accuracy: 0.8637 - val_loss: 0.3527
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8502 - loss: 0.3650 - val_accuracy: 0.8637 - val_loss: 0.3516
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8480 - loss: 0.3662 - val_accuracy: 0.8656 - val_loss: 0.3517
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8531 - loss: 0.3625 - val_accuracy: 0.8631 - val_loss: 0.3509
# Epoch 43/50
# 192/200 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8514 - loss: 0.3673

# %% [markdown]
# # 1. Predict the probabilities for the test set

# %%
from sklearn.metrics import classification_report
y_pred_prob = model_tf.predict(X_test)

y_pred_tf = (y_pred_prob > 0.5).astype(int)
print("TensorFlow Classification Report:")
print(classification_report(y_test, y_pred_tf))

# %% [markdown]
# # Print the structural summary of your deep learning layers

# %%
model_tf.summary()

# %% [markdown]
# # 1. Calculate class weights based on your training data

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
weights = compute_class_weight(
    class_weight='balanced', 
    classes=np.unique(y_train), 
    y=y_train
)
class_weights = {0: weights[0], 1: weights[1]}
print(f"Calculated Class Weights: {class_weights}")

# 2. Re-build a fresh model so it doesn't remember the old training
model_weighted = Sequential()
model_weighted.add(Dense(units=16, activation='relu', input_dim=X_train.shape[1]))
model_weighted.add(Dropout(0.2))
model_weighted.add(Dense(units=8, activation='relu'))
model_weighted.add(Dropout(0.2))
model_weighted.add(Dense(units=1, activation='sigmoid'))

model_weighted.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 3. Train again, passing the class_weight dictionary
history_weighted = model_weighted.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    class_weight=class_weights,  # <-- The magic line
    callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)],
    verbose=0 # Suppresses long output logs
)

# 4. Generate the new classification report
y_pred_weighted_prob = model_weighted.predict(X_test)
y_pred_weighted = (y_pred_weighted_prob > 0.5).astype(int)

print("\nWeighted TensorFlow Classification Report:")
print(classification_report(y_test, y_pred_weighted))
# Out:
# Calculated Class Weights: {0: np.float64(0.6213109661385523), 1: np.float64(2.560819462227913)}
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
